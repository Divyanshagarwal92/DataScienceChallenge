# %%
import bson
import nltk
import re
from nltk.corpus import stopwords
import data

# %%
#load data as a list of dictionaries
#Access approach
#dictionary[1]['dataPoint']['smearedSentence']
#dictionary[1][]'dataPoint'['timeEntityTokens']

def loadData( filename):
        b_file = open( filename, 'rb')
        txtfile = open( 'txtfile', 'w')
        bs = b_file.read()
        dictionary = bson.decode_all(bs)
        return dictionary
filename = "PositiveNegativeTimeExerciseDataSet.bson"
list_dictionary = loadData(filename)

# %%
list_dictionary = data.loadData('PositiveNegativeTimeExerciseDataSet.bson')

# %%
sentence = list_dictionary[10]['dataPoint']['smearedSentence']
timeToken = list_dictionary[10]['dataPoint']['timeEntityTokens']
[modified_sentence, timeToken] = data.review_to_words(sentence, timeToken)
print sentence
print modified_sentence
print len(modified_sentence.split())
print timeToken
# Out:
# 8pm Wednesday
#
# 0
# set([u'8pm Wednesday'])

# %%
list_dictionary[1]['dataPoint']
# Out:
# {u'label': u'POSITIVE_TIME',
#  u'rand': 0.308788001537323,
#  u'smearedSentence': u'I did send her an email earlier today confirming 11:30.',
#  u'timeEntityTokens': [u'11:30']}

# %%
import numpy as np
import classifier_set as cs
Y = np.load('labels.npy')
X = np.load('features.npy')
cs.RF(X,Y,10)
# Out:
# Accuracy: 0.964 (+/- 0.006)
# 0.964229223784143

# %%
emailLabel = np.zeros(len(list_dictionary),dtype="int32" )
emailLabel
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
cnt = 0
for dic in list_dictionary:
    if dic['dataPoint']['timeEntityTokens'] == 'NEGATIVE_TIME':
        cnt = cnt + 1

# %%
Y[0]
# Out:
# 1

# %%
#emailFeatureVecs = np.zeros((len(list_dictionary), num_features),dtype="float32")
emailLabel = np.zeros(len(list_dictionary),dtype="int32" )
countP = 0 
countN = 0 
counter = 0
for dic in list_dictionary:
    label = dic['dataPoint']['label']
    #emailFeatureVecs[counter] = getFeatures(dic, model)    
    if label == 'POSITIVE_TIME':
        emailLabel[counter] = 1 
        countP = countP + 1 
    else:
        #print dic['dataPoint']['smearedSentence']
        #print label
        print counter
        emailLabel[counter] = 0 
        countN = countN + 1 
    counter = counter + 1
# Out:
# 74754
# 74755
# 74756
# 74757
# 74758
# 74759
# 74760
# 74761
# 74762
# 74763
# 74764
# 74765
# 74766
# 74767
# 74768
# 74769
# 74770
# 74771
# 74772
# 74773
# 74774
# 74775
# 74776
# 74777
# 74778
# 74779
# 74780
# 74781
# 74782
# 74783
# 74784
# 74785
# 74786
# 74787
# 74788
# 74789
# 74790
# 74791
# 74792
# 74793
# 74794
# 74795
# 74796
# 74797
# 74798
# 74799
# 74800
# 74801
# 74802
# 74803
# 74804
# 74805
# 74806
# 74807
# 74808
# 74809
# 74810
# 74811
# 74812
# 74813
# 74814
# 74815
# 74816
# 74817
# 74818
# 74819
# 74820
# 74821
# 74822
# 74823
# 74824
# 74825
# 74826
# 74827
# 74828
# 74829
# 74830
# 74831
# 74832
# 74833
# 74834
# 74835
# 74836
# 74837
# 74838
# 74839
# 74840
# 74841
# 74842
# 74843
# 74844
# 74845
# 74846
# 74847
# 74848
# 74849
# 74850
# 74851
# 74852
# 74853
# 74854
# 74855
# 74856
# 74857
# 74858
# 74859
# 74860
# 74861
# 74862
# 74863
# 74864
# 74865
# 74866
# 74867
# 74868
# 74869
# 74870
# 74871
# 74872
# 74873
# 74874
# 74875
# 74876
# 74877
# 74878
# ...

# %%
cnt = 0
for i in Y:
    if emailLabel[i] == 0:
        cnt = cnt + 1
print cnt
# Out:
# 80501

# %%
list_dictionary[80000]
# Out:
# {u'_id': ObjectId('5626ba62d4c64c24a245c46d'),
#  u'dataPoint': {u'label': u'NEGATIVE_TIME',
#   u'rand': 0.1469048261642456,
#   u'smearedSentence': u'Unfortunately, I can`t make it on next Friday.',
#   u'timeEntityTokens': [u'on next Friday']}}

# %%
Y[500]
# Out:
# 1
